# %%
# importing library
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
# Loading the file into the dataframe
df = pd.read_csv('po1_data.csv')

# %%
# data wrangling
# inserting column names as given in the project and brief for the data set
column_names = ["Subject ID", "Jitter", "Jitter Abs", "Jitter RAP", "Jitter PPQ5", "Jitter DDPP",
    "Shimmer", "Shimmer Abs", "Shimmer APQ3", "Shimmer APQ5", "Shimmer APQ11", "Shimmer DDAP",
    "Harmonicity AutoCorr", "Harmonicity NHR", "Harmonicity HNR",
    "Pitch Median", "Pitch Mean", "Pitch Std", "Pitch Min", "Pitch Max",
    "Pulse Num", "Pulse Periods", "Pulse Mean", "Pulse Std",
    "Voice Unvoiced", "Voice Breaks Num", "Voice Breaks Degree",
    "UPDRS", "PD Indicator"]
df.columns = column_names

# %%
# Data type of the columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1039 entries, 0 to 1038
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Subject ID            1039 non-null   int64
#  1   Jitter                1039 non-null   float64
#  2   Jitter Abs            1039 non-null   float64
#  3   Jitter RAP            1039 non-null   float64
#  4   Jitter PPQ5           1039 non-null   float64
#  5   Jitter DDPP           1039 non-null   float64
#  6   Shimmer               1039 non-null   float64
#  7   Shimmer Abs           1039 non-null   float64
#  8   Shimmer APQ3          1039 non-null   float64
#  9   Shimmer APQ5          1039 non-null   float64
#  10  Shimmer APQ11         1039 non-null   float64
#  11  Shimmer DDAP          1039 non-null   float64
#  12  Harmonicity AutoCorr  1039 non-null   float64
#  13  Harmonicity NHR       1039 non-null   float64
#  14  Harmonicity HNR       1039 non-null   float64
#  15  Pitch Median          1039 non-null   float64
#  16  Pitch Mean            1039 non-null   float64
#  17  Pitch Std             1039 non-null   float64
#  18  Pitch Min             1039 non-null   float64
#  19  Pitch Max             1039 non-null   float64
#  20  Pulse Num             1039 non-null   int64
#  21  Pulse Periods         1039 non-null   int64
#  22  Pulse Mean            1039 non-null   float64
#  23  Pulse Std             1039 non-null   float64
#  24  Voice Unvoiced        1039 non-null   float64
#  25  Voice Breaks Num      1039 non-null   int64
#  26  Voice Breaks Degree   1039 non-null   float64
#  27  UPDRS                 1039 non-null   int64
#  28  PD Indicator          1039 non-null   int64
# dtypes: float64(23), int64(6)
# memory usage: 235.5 KB

# %%
df.head()
# Out:
#    Subject ID  Jitter  Jitter Abs  Jitter RAP  Jitter PPQ5  Jitter DDPP  \
# 0           1   0.728    0.000038       0.353        0.376        1.059
# 1           1   1.220    0.000074       0.732        0.670        2.196
# 2           1   2.502    0.000123       1.156        1.634        3.469
# 3           1   3.509    0.000167       1.715        1.539        5.145
# 4           1   2.470    0.000126       1.358        1.341        4.075
#
#    Shimmer  Shimmer Abs  Shimmer APQ3  Shimmer APQ5  ...  Pitch Max  \
# 0    5.864        0.642         2.058         3.180  ...    234.505
# 1    8.719        0.875         4.347         5.166  ...    211.442
# 2   13.513        1.273         5.263         8.771  ...    220.230
# 3    9.112        1.040         3.102         4.927  ...    225.162
# 4   10.696        1.256         5.262         7.076  ...    202.812
#
#    Pulse Num  Pulse Periods  Pulse Mean  Pulse Std  Voice Unvoiced  \
# 0        170            169    0.005181   0.000403           2.247
# 1       1431           1427    0.006071   0.000474          10.656
# 2         94             92    0.004910   0.000320           0.000
# 3        117            114    0.004757   0.000380          18.182
# 4         74             73    0.005118   0.000187          23.214
#
#    Voice Breaks Num  Voice Breaks Degree  UPDRS  PD Indicator
# 0                 0                0.000     23             1
# 1                 1                0.178     23             1
# 2                 0                0.000     23             1
# 3                 1               13.318     23             1
# 4                 0                0.000     23             1
#
# [5 rows x 29 columns]

# %%
# dropping the column that are not needed
datas = df.drop(["Subject ID", "UPDRS", "PD Indicator"], axis = 1)
# descriptive statistics of all data 
datas.describe()
# Out:
#             Jitter   Jitter Abs   Jitter RAP  Jitter PPQ5  Jitter DDPP  \
# count  1039.000000  1039.000000  1039.000000  1039.000000  1039.000000
# mean      2.680669     0.000170     1.247387     1.348861     3.742164
# std       1.765515     0.000106     0.979874     1.139160     2.939680
# min       0.190000     0.000006     0.062000     0.081000     0.185000
# 25%       1.509000     0.000095     0.617000     0.664500     1.851500
# 50%       2.398000     0.000151     1.037000     1.127000     3.111000
# 75%       3.413000     0.000229     1.603000     1.695500     4.810000
# max      14.376000     0.000777     8.016000    13.542000    24.048000
#
#            Shimmer  Shimmer Abs  Shimmer APQ3  Shimmer APQ5  Shimmer APQ11  \
# count  1039.000000  1039.000000   1039.000000   1039.000000    1039.000000
# mean     12.922803     1.195296      5.700738      7.986800      12.220556
# std       5.452972     0.420075      3.016411      4.842089       6.016810
# min       1.185000     0.103000      0.496000      0.708000       0.517000
# 25%       9.366000     0.943500      3.702000      5.162500       8.094000
# 50%      12.349000     1.182000      5.136000      7.051000      11.445000
# 75%      15.497500     1.411000      6.953000      9.564620      15.306125
# max      41.137000     2.721000     25.820000     72.860000      44.764000
#
#        ...    Pitch Std    Pitch Min    Pitch Max    Pulse Num  Pulse Periods  \
# count  ...  1039.000000  1039.000000  1039.000000  1039.000000    1039.000000
# mean   ...    27.564113   134.530699   234.921514   109.695861     105.918191
# std    ...    36.686430    47.080115   121.590903   150.091841     149.479959
# min    ...     0.533000    67.957000    85.541000     0.000000       0.000000
# 25%    ...     7.291000   100.836500   143.646500    42.500000      40.500000
# 50%    ...    12.810000   127.266000   196.108000    65.000000      62.000000
# 75%    ...    27.578000   159.792500   264.125500   113.000000     109.000000
# max    ...   293.877000   452.083000   597.974000  1490.000000    1489.000000
#
#         Pulse Mean    Pulse Std  Voice Unvoiced  Voice Breaks Num  \
# count  1039.000000  1039.000000     1039.000000       1039.000000
# mean      0.006547     0.000843       27.709500          1.135707
# std       0.001876     0.000723       20.967781          1.615157
# min       0.002039     0.000055        0.000000          0.000000
# 25%       0.005038     0.000404        8.180000          0.000000
# 50%       0.006486     0.000645       26.531000          1.000000
# 75%       0.007924     0.000980       43.072500          1.000000
# max       0.012070     0.006371       88.158000         12.000000
#
#        Voice Breaks Degree
# count          1039.000000
# mean             12.381948
# std              15.164353
# min               0.000000
# 25%               0.000000
# 50%               5.850000
# 75%              22.294000
# max              69.117000
#
# [8 rows x 26 columns]

# %%
# sectioning the dataset into PPD and healthy according to the PD Indicator
ppd = df[df["PD Indicator"] == 1]
healthy = df[df["PD Indicator"] == 0]

# %%
# dropping the columns that are not needed and descriptive statistics according to its PPD and healthy indicator
ppd_describe = ppd.drop(["Subject ID", "UPDRS", "PD Indicator"], axis = 1).describe()
healthy_describe = healthy.drop(["Subject ID", "UPDRS", "PD Indicator"], axis = 1).describe()

# %%
# showing the descriptive statistics of PPD group includes mean median etc
print("Descriptive Statistics for PPD group: ")
print(ppd_describe)
# Out:
# Descriptive Statistics for PPD group:
#            Jitter  Jitter Abs  Jitter RAP  Jitter PPQ5  Jitter DDPP  \
# count  519.000000  519.000000   519.00000   519.000000   519.000000
# mean     2.854252    0.000188     1.35674     1.475903     4.070214
# std      1.681113    0.000113     0.91818     1.019948     2.754580
# min      0.195000    0.000010     0.06200     0.091000     0.185000
# 25%      1.717500    0.000105     0.75250     0.802500     2.257500
# 50%      2.627000    0.000169     1.17900     1.257000     3.538000
# 75%      3.647500    0.000258     1.78050     1.931500     5.341500
# max     10.439000    0.000713     6.12500     7.205000    18.375000
#
#           Shimmer  Shimmer Abs  Shimmer APQ3  Shimmer APQ5  Shimmer APQ11  \
# count  519.000000   519.000000    519.000000    519.000000     519.000000
# mean    12.976704     1.207135      5.647055      7.880583      13.107382
# std      4.710630     0.365432      2.486535      3.514261       6.328493
# min      2.171000     0.229000      0.565000      1.025000       0.517000
# 25%     10.156500     1.000000      3.989000      5.474000       8.984500
# 50%     12.807000     1.226000      5.263000      7.461000      12.105000
# 75%     15.343500     1.406500      6.813000      9.525620      16.254000
# max     41.137000     2.689000     16.641000     31.750000      44.764000
#
#        ...   Pitch Std   Pitch Min   Pitch Max    Pulse Num  Pulse Periods  \
# count  ...  519.000000  519.000000  519.000000   519.000000     519.000000
# mean   ...   23.134103  131.737957  218.000007   115.813102     112.915222
# std    ...   34.352187   42.932069  109.482146   178.694055     178.532436
# min    ...    0.533000   67.957000   85.541000     0.000000       0.000000
# 25%    ...    7.017000   99.706500  141.431000    42.500000      41.000000
# 50%    ...   10.805000  124.099000  187.183000    67.000000      65.000000
# 75%    ...   21.795500  156.731500  243.320500   111.000000     109.000000
# max    ...  293.877000  440.262000  597.974000  1490.000000    1489.000000
#
#        Pulse Mean   Pulse Std  Voice Unvoiced  Voice Breaks Num  \
# count  519.000000  519.000000      519.000000        519.000000
# mean     0.006701    0.000801       25.172592          1.007707
# std      0.001869    0.000737       20.651862          1.470409
# min      0.002211    0.000055        0.000000          0.000000
# 25%      0.005070    0.000383        5.796000          0.000000
# 50%      0.006673    0.000619       23.077000          1.000000
# 75%      0.007986    0.000896       38.936000          1.000000
# max      0.012070    0.006371       88.158000         11.000000
#
#        Voice Breaks Degree
# count           519.000000
# mean             10.478424
# std              13.768271
# min               0.000000
# 25%               0.000000
# 50%               3.324000
# 75%              18.738000
# max              60.298000
#
# [8 rows x 26 columns]

# %%
# showing the descriptive statistics of healthy group includes mean median etc
print("Descriptive Statistics for healthy group: ")
print (healthy_describe)
# Out:
# Descriptive Statistics for healthy group:
#            Jitter  Jitter Abs  Jitter RAP  Jitter PPQ5  Jitter DDPP  \
# count  520.000000  520.000000  520.000000   520.000000   520.000000
# mean     2.507421    0.000153    1.138244     1.222062     3.414746
# std      1.831170    0.000096    1.027124     1.234842     3.081448
# min      0.190000    0.000006    0.084000     0.081000     0.252000
# 25%      1.381750    0.000087    0.528000     0.578250     1.584000
# 50%      2.214000    0.000134    0.907000     0.967500     2.720000
# 75%      3.052000    0.000202    1.401000     1.467250     4.204000
# max     14.376000    0.000777    8.016000    13.542000    24.048000
#
#           Shimmer  Shimmer Abs  Shimmer APQ3  Shimmer APQ5  Shimmer APQ11  \
# count  520.000000   520.000000    520.000000    520.000000     520.000000
# mean    12.869006     1.183479      5.754319      8.092812      11.335434
# std      6.108741     0.468361      3.467099      5.877320       5.555173
# min      1.185000     0.103000      0.496000      0.708000       0.982000
# 25%      8.768000     0.887000      3.486500      4.820000       7.504250
# 50%     11.785000     1.138000      4.886500      6.644000      10.775500
# 75%     15.544000     1.412500      7.114000      9.685750      13.724000
# max     39.874000     2.721000     25.820000     72.860000      41.280000
#
#        ...   Pitch Std   Pitch Min   Pitch Max   Pulse Num  Pulse Periods  \
# count  ...  520.000000  520.000000  520.000000  520.000000     520.000000
# mean   ...   31.985604  137.318069  251.810481  103.590385      98.934615
# std    ...   38.402826   50.772821  130.511785  114.500269     113.041041
# min    ...    0.626000   70.502000  100.010000    5.000000       4.000000
# 25%    ...    7.797000  101.172500  148.153000   42.750000      40.000000
# 50%    ...   14.972000  128.539500  202.064500   62.000000      58.500000
# 75%    ...   35.996750  160.407750  323.134000  118.000000     111.250000
# max    ...  162.396000  452.083000  526.410000  805.000000     798.000000
#
#        Pulse Mean   Pulse Std  Voice Unvoiced  Voice Breaks Num  \
# count  520.000000  520.000000      520.000000        520.000000
# mean     0.006393    0.000885       30.241529          1.263462
# std      0.001872    0.000708       20.994251          1.739768
# min      0.002039    0.000057        0.000000          0.000000
# 25%      0.005035    0.000428       11.111000          0.000000
# 50%      0.006147    0.000663       29.992000          1.000000
# 75%      0.007754    0.001053       47.219500          2.000000
# max      0.010837    0.004075       85.000000         12.000000
#
#        Voice Breaks Degree
# count           520.000000
# mean             14.281812
# std              16.231924
# min               0.000000
# 25%               0.000000
# 50%               8.863500
# 75%              25.478000
# max              69.117000
#
# [8 rows x 26 columns]

# %%
# excluding the columns and number of rows for arranging box plot of different features
visualiseBox = df.columns[1:-2]
numRows = (len(visualiseBox) + 1) // 2

# %%
# number of rows and columns and the width and height of the grid
fig, axes = plt.subplots(numRows, 2, figsize=(15, 100))
fig.suptitle("Box Plot of Features for PPD and Healthy Groups by PD Indicator")
for i, feature in enumerate(visualiseBox):
    row = i // 2 #to find out the row index in the grid
    col = i % 2 #to find out the column index in the grid
    
    plt.sca(axes[row, col])
    plt.boxplot([ppd[feature], healthy[feature]], labels=["PPD", "Healthy"])
    plt.title(feature)
plt.tight_layout()
plt.show()

# %%
# performing t-tests for each feature
salientFeatures = []
sigLevel = 0.05  # Significance level

for feature in visualiseBox:
    ppd_values = ppd[feature]
    healthy_values = healthy[feature]
    
    t_statistic, p_value = stats.ttest_ind(ppd_values, healthy_values)
    
    if p_value < sigLevel:
        salientFeatures.append(feature)
        print(f"Feature: {feature}")
        print(f"T-Test - T-statistic: {t_statistic}, p-value: {p_value}")
        print("Significant difference found!\n")
    else:
        print(f"Feature: {feature}")
        print(f"T-Test - T-statistic: {t_statistic}, p-value: {p_value}")
        print("No significant difference found.\n")

print("Features with significant differences:", salientFeatures)
# Out:
# Feature: Jitter
# T-Test - T-statistic: 3.179957964528876, p-value: 0.0015166306694224796
# Significant difference found!
#
# Feature: Jitter Abs
# T-Test - T-statistic: 5.483006945218922, p-value: 5.2517055998338165e-08
# Significant difference found!
#
# Feature: Jitter RAP
# T-Test - T-statistic: 3.6145918292716948, p-value: 0.00031527323464814003
# Significant difference found!
#
# Feature: Jitter PPQ5
# T-Test - T-statistic: 3.612105844249591, p-value: 0.00031827364307247797
# Significant difference found!
#
# Feature: Jitter DDPP
# T-Test - T-statistic: 3.614413628944979, p-value: 0.0003154874244601272
# Significant difference found!
#
# Feature: Shimmer
# T-Test - T-statistic: 0.3181733112700877, p-value: 0.7504175388743878
# No significant difference found.
#
# Feature: Shimmer Abs
# T-Test - T-statistic: 0.9075226884388011, p-value: 0.36434129477650257
# No significant difference found.
#
# Feature: Shimmer APQ3
# T-Test - T-statistic: -0.5729283921523461, p-value: 0.5668173829668095
# No significant difference found.
#
# Feature: Shimmer APQ5
# T-Test - T-statistic: -0.7062277064892245, p-value: 0.4802051759460255
# No significant difference found.
#
# Feature: Shimmer APQ11
# T-Test - T-statistic: 4.796424500273657, p-value: 1.8515208471407666e-06
# Significant difference found!
#
# Feature: Shimmer DDAP
# T-Test - T-statistic: -0.5729780279081053, p-value: 0.5667837868983056
# No significant difference found.
#
# Feature: Harmonicity AutoCorr
# T-Test - T-statistic: 2.600068541006031, p-value: 0.009453025535708372
# Significant difference found!
#
# Feature: Harmonicity NHR
# T-Test - T-statistic: -2.4356026429379405, p-value: 0.015034614259724334
# Significant difference found!
#
# Feature: Harmonicity HNR
# T-Test - T-statistic: 1.297973260614607, p-value: 0.19458514112654204
# No significant difference found.
#
# Feature: Pitch Median
# T-Test - T-statistic: -2.724924363612065, p-value: 0.006539846963928817
# Significant difference found!
#
# Feature: Pitch Mean
# T-Test - T-statistic: -3.34285038933219, p-value: 0.0008588589900376986
# Significant difference found!
#
# Feature: Pitch Std
# T-Test - T-statistic: -3.915311025321047, p-value: 9.618599277227429e-05
# Significant difference found!
#
# Feature: Pitch Min
# T-Test - T-statistic: -1.9126626178106443, p-value: 0.05606648983538763
# No significant difference found.
#
# Feature: Pitch Max
# T-Test - T-statistic: -4.523360620992199, p-value: 6.788944027612661e-06
# Significant difference found!
#
# Feature: Pulse Num
# T-Test - T-statistic: 1.3129241180569509, p-value: 0.1894989816058314
# No significant difference found.
#
# Feature: Pulse Periods
# T-Test - T-statistic: 1.5082980320999853, p-value: 0.13178285371818493
# No significant difference found.
#
# Feature: Pulse Mean
# T-Test - T-statistic: 2.6512240355078025, p-value: 0.008142328983202565
# Significant difference found!
#
# Feature: Pulse Std
# T-Test - T-statistic: -1.8792403620913751, p-value: 0.060491938338863994
# No significant difference found.
#
# Feature: Voice Unvoiced
# T-Test - T-statistic: -3.9231227451992123, p-value: 9.316306562828443e-05
# Significant difference found!
#
# Feature: Voice Breaks Num
# T-Test - T-statistic: -2.5588411604941084, p-value: 0.01064320298929153
# Significant difference found!
#
# Feature: Voice Breaks Degree
# T-Test - T-statistic: -4.07249380583184, p-value: 5.005424071729823e-05
# Significant difference found!
#
# Features with significant differences: ['Jitter', 'Jitter Abs', 'Jitter RAP', 'Jitter PPQ5', 'Jitter DDPP', 'Shimmer APQ11', 'Harmonicity AutoCorr', 'Harmonicity NHR', 'Pitch Median', 'Pitch Mean', 'Pitch Std', 'Pitch Max', 'Pulse Mean', 'Voice Unvoiced', 'Voice Breaks Num', 'Voice Breaks Degree']

# %%
data = df.drop(columns=["Subject ID", "PD Indicator"])

correlation_matrix = data.corr()

# using a heatmap to visualise the correlation matrix
plt.figure(figsize=(18, 10))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", center=0)
plt.title("Correlation Heatmap")
plt.show()

# correlation of features with UPDRS scores
updrs_correlations = correlation_matrix["UPDRS"].sort_values(ascending=False)
print("Correlations with UPDRS score:\n")
print(updrs_correlations)
# Out:
# Correlations with UPDRS score:
#
# UPDRS                   1.000000
# Shimmer APQ11           0.200289
# Jitter Abs              0.178234
# Jitter DDPP             0.165889
# Jitter RAP              0.165883
# Jitter PPQ5             0.153176
# Jitter                  0.140793
# Shimmer Abs             0.088770
# Shimmer                 0.081179
# Shimmer DDAP            0.046945
# Shimmer APQ3            0.046942
# Shimmer APQ5            0.038606
# Pulse Mean              0.037482
# Voice Unvoiced          0.018960
# Pulse Periods           0.018790
# Pulse Num               0.014757
# Harmonicity AutoCorr    0.008356
# Harmonicity NHR        -0.006891
# Pitch Min              -0.029427
# Harmonicity HNR        -0.030836
# Pulse Std              -0.039830
# Voice Breaks Num       -0.050632
# Pitch Median           -0.061680
# Pitch Mean             -0.065595
# Voice Breaks Degree    -0.069978
# Pitch Std              -0.071718
# Pitch Max              -0.079567
# Name: UPDRS, dtype: float64

# %%
#calculating meanDiff
meanDiff = []
for feature in visualiseBox:
    ppd_mean = ppd[feature].mean()
    healthy_mean = healthy[feature].mean()
    
    mean_difference = abs(ppd_mean - healthy_mean)
    meanDiff.append((feature, mean_difference))
#sorting in descending order
meanDiff.sort(key=lambda x: x[1], reverse=True)

#to get the top five feature 
top_5_features = meanDiff[:5]

print("Top 5 features with highest mean differences:")

#printing those top five features
for feature, diff in top_5_features:
    print(f"Feature: {feature}, Mean Difference: {diff}")
# Out:
# Top 5 features with highest mean differences:
# Feature: Pitch Max, Mean Difference: 33.810474064028426
# Feature: Pulse Periods, Mean Difference: 13.980606195346084
# Feature: Pulse Num, Mean Difference: 12.222717504075874
# Feature: Pitch Mean, Mean Difference: 11.558032229138888
# Feature: Pitch Median, Mean Difference: 9.447163246628122
